# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('score.sc',header=0, sep='\s+')
print list(df)
# Out:
# ['total_score', 'fa_rep', 'hbond_sc', 'all_cst', 'tot_pstat_pm', 'tot_nlpstat_pm', 'tot_burunsat_pm', 'tot_hbond_pm', 'tot_NLconts_pm', 'tot_nlsurfaceE_pm', 'tot_total_charge', 'tot_total_pos_charges', 'tot_total_neg_charges', 'tot_seq_recovery', 'SR_1', 'SR_1_total_score', 'SR_1_fa_rep', 'SR_1_hbond_sc', 'SR_1_all_cst', 'SR_1_hbond_pm', 'SR_1_burunsat_pm', 'SR_1_pstat_pm', 'SR_1_nlpstat_pm', 'SR_2', 'SR_2_total_score', 'SR_2_fa_rep', 'SR_2_hbond_sc', 'SR_2_all_cst', 'SR_2_hbond_pm', 'SR_2_burunsat_pm', 'SR_2_pstat_pm', 'SR_2_nlpstat_pm', 'SR_3', 'SR_3_total_score', 'SR_3_fa_rep', 'SR_3_hbond_sc', 'SR_3_all_cst', 'SR_3_hbond_pm', 'SR_3_burunsat_pm', 'SR_3_pstat_pm', 'SR_3_nlpstat_pm', 'SR_4', 'SR_4_total_score', 'SR_4_fa_rep', 'SR_4_hbond_sc', 'SR_4_all_cst', 'SR_4_interf_E_1_2', 'SR_4_dsasa_1_2', 'SR_4_hbond_pm', 'SR_4_burunsat_pm', 'Transform_accept_ratio', 'allcst', 'description']

# %%
var= 'SR_4_interf_E_1_2'
cst_filtered = df[ df.allcst < 180 ]
lowetotalscore = cst_filtered.sort_values('total_score').head(10)
lowetotalscore.sort_values(var)[['description','allcst','total_score',var]]
# Out:
#       description  allcst  total_score  SR_4_interf_E_1_2
# 6  1oim.dock_0007  151.68       -83.20              -0.59
# 2  1oim.dock_0003  165.09       -80.62              -0.39
# 0  1oim.dock_0001  155.18       -88.41               0.31
# 3  1oim.dock_0004  159.51       -64.47               1.07
# 4  1oim.dock_0005  161.27       -78.34               1.22
# 5  1oim.dock_0006  177.46       -86.27               1.63
# 1  1oim.dock_0002  170.31       -76.62               2.53

# %%
df
#df[['all_cst','SR_1_all_cst','SR_2_all_cst','SR_3_all_cst','SR_4_all_cst','description','SR_4_all_cst','total_score']]
# Out:
#    total_score  fa_rep  hbond_sc  all_cst  tot_pstat_pm  tot_nlpstat_pm  \
# 0       -88.41  319.68    -41.38      0.0          0.75            0.74
# 1       -76.62  324.03    -40.86      0.0          0.76            0.75
# 2       -80.62  320.54    -41.44      0.0          0.75            0.76
# 3       -64.47  324.24    -40.82      0.0          0.75            0.75
# 4       -78.34  322.48    -41.66      0.0          0.75            0.74
# 5       -86.27  320.05    -40.95      0.0          0.77            0.75
# 6       -83.20  318.17    -44.53      0.0          0.75            0.73
#
#    tot_burunsat_pm  tot_hbond_pm  tot_NLconts_pm  tot_nlsurfaceE_pm  \
# 0            184.0         421.0           124.0               6.01
# 1            181.0         419.0           126.0               5.82
# 2            181.0         418.0           124.0               5.77
# 3            184.0         414.0           125.0               5.46
# ...
