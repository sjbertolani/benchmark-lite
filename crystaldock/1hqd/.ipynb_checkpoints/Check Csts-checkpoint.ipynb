# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('score.sc',header=0, sep='\s+')
#df['all_cst']

# %%
print list(df)
df[['allcst','SR_1_all_cst','SR_2_all_cst','SR_3_all_cst','SR_4_all_cst','description','SR_4_all_cst','total_score']].sort('allcst')
# Out:
# ['total_score', 'fa_rep', 'hbond_sc', 'all_cst', 'tot_pstat_pm', 'tot_nlpstat_pm', 'tot_burunsat_pm', 'tot_hbond_pm', 'tot_NLconts_pm', 'tot_nlsurfaceE_pm', 'tot_total_charge', 'tot_total_pos_charges', 'tot_total_neg_charges', 'tot_seq_recovery', 'SR_1', 'SR_1_total_score', 'SR_1_fa_rep', 'SR_1_hbond_sc', 'SR_1_all_cst', 'SR_1_hbond_pm', 'SR_1_burunsat_pm', 'SR_1_pstat_pm', 'SR_1_nlpstat_pm', 'SR_2', 'SR_2_total_score', 'SR_2_fa_rep', 'SR_2_hbond_sc', 'SR_2_all_cst', 'SR_2_hbond_pm', 'SR_2_burunsat_pm', 'SR_2_pstat_pm', 'SR_2_nlpstat_pm', 'SR_3', 'SR_3_total_score', 'SR_3_fa_rep', 'SR_3_hbond_sc', 'SR_3_all_cst', 'SR_3_hbond_pm', 'SR_3_burunsat_pm', 'SR_3_pstat_pm', 'SR_3_nlpstat_pm', 'SR_4', 'SR_4_total_score', 'SR_4_fa_rep', 'SR_4_hbond_sc', 'SR_4_all_cst', 'SR_4_interf_E_1_2', 'SR_4_dsasa_1_2', 'SR_4_hbond_pm', 'SR_4_burunsat_pm', 'Transform_accept_ratio', 'allcst', 'description']
# /home/steve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#     allcst  SR_1_all_cst  SR_2_all_cst  SR_3_all_cst  SR_4_all_cst  \
# 9    12.22          6.11          6.11          5.98          0.13
# 10   12.39          6.20          6.20          6.01          0.18
# 7    12.41          6.21          6.21          6.12          0.09
# 15   12.44          6.22          6.22          6.09          0.13
# 8    12.59          6.30          6.30          5.02          1.28
# 6    12.85          6.42          6.42          5.49          0.93
# 13   12.95          6.47          6.47          5.86          0.62
# 3    13.11          6.55          6.55          4.95          1.61
# 11   13.62          6.81          6.81          5.94          0.87
# 19   13.64          6.82          6.82          6.12          0.70
# 5    13.93          6.96          6.96          5.42          1.54
# 18   14.26          7.13          7.13          4.24          2.89
# 17   14.78          7.39          7.39          6.19          1.20
# 4    16.00          8.00          8.00          5.34          2.66
# 14   18.64          9.32          9.32          7.51          1.81
# 2    20.42         10.21         10.21          7.30          2.92
# 1    20.47         10.23         10.23          7.21          3.03
# 12   25.09         12.55         12.55          6.63          5.92
# 0    25.48         12.74         12.74          5.52          7.22
# 16   28.14         14.07         14.07          5.22          8.86
#
#        description  SR_4_all_cst  total_score
# 9   1hqd.dock_0010          0.13      -365.53
# 10  1hqd.dock_0011          0.18      -338.41
# 7   1hqd.dock_0008          0.09      -363.16
# 15  1hqd.dock_0016          0.13      -346.88
# 8   1hqd.dock_0009          1.28      -370.52
# 6   1hqd.dock_0007          0.93      -356.76
# 13  1hqd.dock_0014          0.62      -363.31
# 3   1hqd.dock_0004          1.61      -364.18
# 11  1hqd.dock_0012          0.87      -365.10
# 19  1hqd.dock_0020          0.70      -367.05
# 5   1hqd.dock_0006          1.54      -359.71
# 18  1hqd.dock_0019          2.89      -360.37
# 17  1hqd.dock_0018          1.20      -355.14
# 4   1hqd.dock_0005          2.66      -352.16
# 14  1hqd.dock_0015          1.81      -351.98
# 2   1hqd.dock_0003          2.92      -345.75
# 1   1hqd.dock_0002          3.03      -366.81
# 12  1hqd.dock_0013          5.92      -352.43
# 0   1hqd.dock_0001          7.22      -361.92
# 16  1hqd.dock_0017          8.86      -356.16
